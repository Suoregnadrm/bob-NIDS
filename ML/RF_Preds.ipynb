# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
import joblib

# %%
df = pd.read_csv("update_dataset_pred.csv")

# %%
df
# Out:
#         ip.src     ip.dst  ip.len  ip.flags.df  ip.flags.mf  ip.fragment  \
# 0    835583506  167772164      52         True        False          0.0
# 1    167772164  835583506      96         True        False          0.0
# 2    835583506  167772164      52         True        False          0.0
# 3    167772164  835583506      96         True        False          0.0
# 4    835583506  167772164      52         True        False          0.0
# ..         ...        ...     ...          ...          ...          ...
# 662  835583506  167772164      52         True        False          0.0
# 663  167772164  835583506      96         True        False          0.0
# 664  835583506  167772164      52         True        False          0.0
# 665  167772164  835583506      96         True        False          0.0
# 666  835583506  167772164      52         True        False          0.0
#
#      ip.fragment.count  ip.fragments  ip.ttl  ip.proto  ...  tcp.flags  \
# 0                  0.0           0.0      50         6  ...         16
# 1                  0.0           0.0      64         6  ...         24
# 2                  0.0           0.0      50         6  ...         16
# 3                  0.0           0.0      64         6  ...         24
# 4                  0.0           0.0      50         6  ...         16
# ..                 ...           ...     ...       ...  ...        ...
# 662                0.0           0.0      50         6  ...         16
# 663                0.0           0.0      64         6  ...         24
# 664                0.0           0.0      50         6  ...         16
# 665                0.0           0.0      64         6  ...         24
# 666                0.0           0.0      50         6  ...         16
#
#      tcp.analysis.ack_rtt  tcp.segments  tcp.reassembled.length  http.request  \
# 0                0.000000           0.0                     0.0             0
# 1                0.000000           0.0                     0.0             0
# 2                0.061417           0.0                     0.0             0
# 3                0.000000           0.0                     0.0             0
# 4                0.061231           0.0                     0.0             0
# ..                    ...           ...                     ...           ...
# 662              0.030261           0.0                     0.0             0
# 663              0.000000           0.0                     0.0             0
# 664              0.030380           0.0                     0.0             0
# 665              0.000000           0.0                     0.0             0
# 666              0.029605           0.0                     0.0             0
#
#      udp.port  frame.time_relative  frame.time_delta  tcp.time_relative  \
# 0         0.0             0.000000          0.000000           0.000000
# 1         0.0             0.450849          0.450849           0.450849
# 2         0.0             0.512266          0.061417           0.512266
# 3         0.0             0.962739          0.450473           0.962739
# 4         0.0             1.023970          0.061231           1.023970
# ..        ...                  ...               ...                ...
# 662       0.0            58.881114          0.030261          58.881114
# 663       0.0            59.362849          0.481735          59.362849
# 664       0.0            59.393229          0.030380          59.393229
# 665       0.0            59.874791          0.481562          59.874791
# 666       0.0            59.904396          0.029605          59.904396
#
#      tcp.time_delta
# 0          0.000000
# 1          0.450849
# 2          0.061417
# 3          0.450473
# 4          0.061231
# ..              ...
# 662        0.030261
# 663        0.481735
# 664        0.030380
# 665        0.481562
# 666        0.029605
#
# [667 rows x 26 columns]

# %%
le = LabelEncoder()

for column in df.select_dtypes(include=['object']).columns:
    df[column] = le.fit_transform(df[column])

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# %%
model = joblib.load("my_random_forest.joblib")

# %%
pred = model.predict(X_scaled)

# %%
set(pred)
# Out:
# {'normal', 'probe'}
